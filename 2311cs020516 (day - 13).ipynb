# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset("diamonds")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.sample(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 46018   0.53      Ideal     E     VS2   62.0   55.0   1727  5.21  5.17  3.22
# 27125   2.04  Very Good     I     VS2   60.3   59.0  17315  8.18  8.20  4.94
# 39650   0.50  Very Good     I     SI1   63.2   57.0   1087  5.07  5.09  3.21
# 11562   1.01       Fair     E     SI1   64.7   56.0   5034  6.34  6.27  4.08
# 10789   1.00       Fair     H     VS2   64.8   62.0   4861  6.22  6.13  4.00
# 9295    0.91    Premium     G     VS1   62.5   61.0   4570  6.17  6.05  3.82
# 46503   0.53       Fair     E     VS1   62.3   67.0   1778  5.22  5.11  3.22
# 36661   0.38      Ideal     G    VVS1   61.2   54.0    949  4.69  4.72  2.88
# 9681    1.00      Ideal     I     SI1   62.5   56.0   4649  6.38  6.41  4.00
# 17018   1.01       Good     F     VS1   59.0   62.0   6794  6.56  6.60  3.88

# %%
df['color'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df = sns.load_dataset("taxis")
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(44/6430)*100
# Out:
# 0.6842923794712287

# %%
(df.isnull().sum()/6433)*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
df.drop('pickup_zone',axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.drop('pickup_zone',axis=1,inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop(['payment','color','total'],axis=1)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls                      dropoff_zone pickup_borough  \
# ...

# %%
df.drop(['pickup','dropoff'],axis=1,inplace = True)

# %%
df
# Out:
#       passengers  distance  fare   tip  tolls  \
# 0              1      1.60   7.0  2.15    0.0
# 1              1      0.79   5.0  0.00    0.0
# 2              1      1.37   7.5  2.36    0.0
# 3              1      7.70  27.0  6.15    0.0
# 4              3      2.16   9.0  1.10    0.0
# ...          ...       ...   ...   ...    ...
# 6428           1      0.75   4.5  1.06    0.0
# 6429           1     18.74  58.0  0.00    0.0
# 6430           1      4.14  16.0  0.00    0.0
# 6431           1      1.12   6.0  0.00    0.0
# 6432           1      3.85  15.0  3.36    0.0
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# ...

# %%
df.drop(['passengers'],axis=1,inplace=True)

# %%
df
# Out:
#       distance  fare   tip  tolls                      dropoff_zone  \
# 0         1.60   7.0  2.15    0.0               UN/Turtle Bay South
# 1         0.79   5.0  0.00    0.0             Upper West Side South
# 2         1.37   7.5  2.36    0.0                      West Village
# 3         7.70  27.0  6.15    0.0                    Yorkville West
# 4         2.16   9.0  1.10    0.0                    Yorkville West
# ...        ...   ...   ...    ...                               ...
# 6428      0.75   4.5  1.06    0.0              Central Harlem North
# 6429     18.74  58.0  0.00    0.0  East Concourse/Concourse Village
# 6430      4.14  16.0  0.00    0.0                    Bushwick North
# 6431      1.12   6.0  0.00    0.0      East Flatbush/Remsen Village
# 6432      3.85  15.0  3.36    0.0                   Windsor Terrace
#
#      pickup_borough dropoff_borough
# 0         Manhattan       Manhattan
# 1         Manhattan       Manhattan
# 2         Manhattan       Manhattan
# ...

# %%
df.drop([2,3,6428],axis = 0,inplace=True)

# %%
df
# Out:
#       distance  fare   tip  tolls                      dropoff_zone  \
# 0         1.60   7.0  2.15    0.0               UN/Turtle Bay South
# 1         0.79   5.0  0.00    0.0             Upper West Side South
# 4         2.16   9.0  1.10    0.0                    Yorkville West
# 5         0.49   7.5  2.16    0.0                      Midtown East
# 6         3.65  13.0  2.00    0.0           Two Bridges/Seward Park
# ...        ...   ...   ...    ...                               ...
# 6427      7.07  20.0  0.00    0.0                 East Harlem South
# 6429     18.74  58.0  0.00    0.0  East Concourse/Concourse Village
# 6430      4.14  16.0  0.00    0.0                    Bushwick North
# 6431      1.12   6.0  0.00    0.0      East Flatbush/Remsen Village
# 6432      3.85  15.0  3.36    0.0                   Windsor Terrace
#
#      pickup_borough dropoff_borough
# 0         Manhattan       Manhattan
# 1         Manhattan       Manhattan
# 4         Manhattan       Manhattan
# ...
